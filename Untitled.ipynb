# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot([1,90,3,4], 'ro')
plt.ylabel("the numbers i passed")
plt.axis([0,10000000,0,10000000])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
